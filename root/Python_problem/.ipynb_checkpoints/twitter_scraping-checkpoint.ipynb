# %%
import os
import pandas as pd
import tweepy
from tweepy import OAuthHandler
import json

# %%
ACCESS_TOKEN = os.getenv('ACCESS_TOKEN')
ACCESS_TOKEN_SECRET = os.getenv('ACCESS_TOKEN_SECRET')
CONSUMER_KEY = os.getenv('CONSUMER_KEY')
CONSUMER_SECRET = os.getenv('CONSUMER_SECRET')

# %%
class fetchTweets():
    def __init__(self):
        try:
            auth = OAuthHandler(CONSUMER_KEY, CONSUMER_SECRET)
            auth.set_access_token(ACCESS_TOKEN, ACCESS_TOKEN_SECRET)
            
            self.api = tweepy.API(auth, wait_on_rate_limit=True, wait_on_rate_limit_notify=True)

        except tweepy.TweepError as e:
            print(f'Error: Twitter Authentication Failed - {str(e)}')
            
    def get_tweets(self, screen_name):
        all_tweets = []
        
        new_tweets = self.api.user_timeline(screen_name=screen_name, count=100, tweet_mode='extended')
        
        all_tweets.extend(new_tweets)
        
        oldest = all_tweets[-1].id - 1
        
        while len(new_tweets) > 0:
            print(f"Getting tweets before {oldest}")
            
            new_tweets = self.api.user_timeline(screen_name=screen_name, count=100, max_id=oldest, tweet_mode='extended')
            
            all_tweets.extend(new_tweets)
            
            oldest = all_tweets[-1].id - 1
            
            print(f"{len(all_tweets)} tweets have been scraped")
        return all_tweets

# %%
twitter = fetchTweets()

# %%
tweets = twitter.get_tweets('midasIIITD')
# Out:
# Getting tweets before 1087386718485925887
# 200 tweets have been scraped
# Getting tweets before 1037043189843091456
# 294 tweets have been scraped
# Getting tweets before 1021377705084739583
# 294 tweets have been scraped

# %%
def save_jsonl(tweets):
    with open('tweets.jsonl', 'w') as f:
        for tweet in tweets:
            json.dump(tweet._json, f)
            f.write('\n')

# %%
save_jsonl(tweets)

# %%
def parse_jsonl(filename):
    tweets_dict = {}
    
    with open(filename) as f:
        for line in f:
            tweet = json.loads(line)
            images = tweet['entities'].get('media', [])
            tweets_dict.setdefault('text', []).append(tweet['full_text'])
            tweets_dict.setdefault('datetime', []).append(tweet['created_at'])
            tweets_dict.setdefault('favorite_count', []).append(tweet['favorite_count'])
            tweets_dict.setdefault('retweet_count', []).append(tweet['retweet_count'])
            tweets_dict.setdefault('media', []).append(len(images))

    return tweets_dict

# %%
def display_table(tweets_dict):
    df = pd.DataFrame.from_dict(tweets_dict)
    ordered_columns = ['text', 'datetime', 'favorite_count', 'retweet_count', 'media']
    df = df.reindex(columns=ordered_columns)
    df = df.replace('\n', ' ', regex=True)
    df['media'] = df['media'].map({0: 'None'}).fillna(df['media'])
    df['datetime'] = pd.to_datetime(table['datetime'])
    
    return df

# %%
parsed_tweets = parse_jsonl('tweets.jsonl')

# %%
table = display_table(parsed_tweets)

# %%
table
# Out:
#                                                   text  \
# 0    BigMM 2019 : IEEE BigMM 2019 – Call for Worksh...
# 1    Congratulations @midasIIITD team, Rohan, Prady...
# 2    We have emailed the task details to all shortl...
# 3    IEEE BigMM 2019 - Call for Workshop Proposals....
# 4    Congratulations! Arijit, Ramit, @debanjanbhucs...
# 5    We will be releasing a very interesting task t...
# 6    RT @hcdiiitd: Last day to register for #Portfo...
# 7    @ACMMM19 @sigmm @TheOfficialACM @acmmmsys @ACM...
# 8    RT @ACMMM19: The paper deadline is approaching...
# 9    RT @kaggle: Bookmark this amazing library of i...
# 10   Awesome members of our @midasIIITD team who ar...
# 11       @saanidhi @ACMMM19 Before Friday, 15th March.
# 12   We are glad to inform that Adobe is launching ...
# 13   We will email tasks to all shortlisted candida...
# 14   @ACMMM19 @ACM_MM2018 @acmmm17 @sigmm @ACM Less...
# 15   RT @kdnuggets: Face Recognition using One-Shot...
# 16   @AvinashSwamina2 @IIITDelhi No. They will be g...
# 17   We are in the process of finalizing the shortl...
# 18   @ylecun @NilayShri @the_dhumketu @debanjanbhuc...
# 19   RT @kdnuggets: Python Data Science for Beginne...
# 20   RT @stanfordnlp: Useful feature of our Python ...
# 21   @NilayShri @NilayShri, Certain thing! The next...
# 22   At @midasIIITD, we not only work hard but also...
# 23   Considering several requests to extend the dea...
# 24   RT @jeremyphoward: 39 studies about human perc...
# 25             Correction:   @midasIIITD at @IIITDelhi
# 26   Thanks much to all aspirants who have applied ...
# 27   RT @kdnuggets: Keras Hyperparameter Tuning in ...
# 28   RT @RatnRajiv: Great meeting with @midasIIITD ...
# 29   Correction: They have published the following ...
# ..                                                 ...
# 264  RT @TensorFlow: TensorFlow 1.10.0 has been rel...
# 265  @midasIIITD is looking for motivated IIITD MTe...
# 266  @IIITDelhi @ponguru @RatnRajiv The results of ...
# 267  RT @IIITDelhi: @midasIIITD has secured rank 1 ...
# 268  RT @kdnuggets: Comparison of Top 6 Python NLP ...
# 269  Check more details of the 20th IEEE Internatio...
# 270  MR2AMC@ISM 2018 will be organized by @RatnRaji...
# 271  Our workshop proposal named, "MR2AMC: Multimod...
# 272  @NUSComputing Congratulations Abdelhak and Pro...
# 273  RT @goodfellow_ian: One of the most anticipate...
# 274     @the_dhumketu Great to have you in @midasIIITD
# 275  Congratulation @soujanyaporia for being appoin...
# 276  @IIITDelhi @the_dhumketu Thanks team @midasIII...
# 277  RT @IIITDelhi: Congratulations @midasIIITD int...
# 278  RT @learning_pt: Profile of the 5 Indian under...
# 279  Have a look at the list of accepted papers in ...
# 280  RT @goodfellow_ian: https://t.co/hYiWI7ntyk Te...
# 281  RT @IIITDelhi: Congratulations Dr. @RatnRajiv ...
# 282  RT @ylecun: Jitendra Malik, who directs FAIR-M...
# 283  RT @kdnuggets: .@Bloomberg launches free cours...
# 284  RT @TechAtBloomberg: Missed #PyLondinium18? Wa...
# 285  RT @IIITDelhi: We are delighted to announce th...
# 286  Get ready for the annual technical fest of @II...
# 287  Congratulations Dr. @RatnRajiv and team @midas...
# 288  Congratulations MIDAS @midasIIITD intern Prakh...
# 289    MIDAS@IIITD foundation. https://t.co/LKuzyBHzjm
# 290  It feels great to be the part of @IIITDelhi. h...
# 291  Thank you, @toonzratn for designing the logo o...
# 292  We are on Facebook too. Like our page to get o...
# 293  MIDAS is a group of researchers at IIIT-Delhi ...
#
#                      datetime  favorite_count  retweet_count media
# 0   2019-03-18 02:27:47+00:00               2              0  None
# 1   2019-03-17 14:22:04+00:00              12              4  None
# 2   2019-03-16 14:06:56+00:00               6              0  None
# 3   2019-03-16 09:20:29+00:00               1              1  None
# 4   2019-03-16 09:14:58+00:00               6              2  None
# 5   2019-03-16 05:13:14+00:00               7              2  None
